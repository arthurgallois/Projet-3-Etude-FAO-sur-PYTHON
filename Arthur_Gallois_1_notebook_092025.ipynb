# %% [markdown]
# # Accès aux documents .csv et prévisualisation

# %%
import pandas as pd

# %%
#Création des variables permettant l'accès aux documents CSV
population = pd.read_csv('population.csv')

# %%
aide_alimentaire = pd.read_csv('aide_alimentaire.csv')
dispo_alimentaire = pd.read_csv('dispo_alimentaire.csv')
sous_nutrition = pd.read_csv('sous_nutrition.csv')

# %%
#Taille du document
print('le tableau contient {} observation(s) ou article(s)'.format(population.shape[0]))
print('le tableau contient {} colonne(s)'.format(population.shape[1]))
# Out:
# le tableau contient 1416 observation(s) ou article(s)
# le tableau contient 3 colonne(s)

# %%
#Affichage des 5 premières lignes
display(population.head())
# Out:
#           Zone  Année     Valeur
# 0  Afghanistan   2013  32269.589
# 1  Afghanistan   2014  33370.794
# 2  Afghanistan   2015  34413.603
# 3  Afghanistan   2016  35383.032
# 4  Afghanistan   2017  36296.113

# %%
#Conversion de la valeur population en unités, non en milliers
population['Valeur'] = population['Valeur']*1000

# %%
display(population.head())
# Out:
#           Zone  Année      Valeur
# 0  Afghanistan   2013  32269589.0
# 1  Afghanistan   2014  33370794.0
# 2  Afghanistan   2015  34413603.0
# 3  Afghanistan   2016  35383032.0
# 4  Afghanistan   2017  36296113.0

# %%
#Renommage de la colonne en un nom plus explicite
population.rename(columns={'Valeur': 'Population'})
# Out:
#              Zone  Année  Population
# 0     Afghanistan   2013  32269589.0
# 1     Afghanistan   2014  33370794.0
# 2     Afghanistan   2015  34413603.0
# 3     Afghanistan   2016  35383032.0
# 4     Afghanistan   2017  36296113.0
# ...           ...    ...         ...
# 1411     Zimbabwe   2014  13586707.0
# 1412     Zimbabwe   2015  13814629.0
# 1413     Zimbabwe   2016  14030331.0
# 1414     Zimbabwe   2017  14236595.0
# 1415     Zimbabwe   2018  14438802.0
#
# [1416 rows x 3 columns]

# %%
#Taille de la base de données
print('le tableau contient {} observation(s) ou article(s)'.format(dispo_alimentaire.shape[0]))
print('le tableau contient {} colonne(s)'.format(dispo_alimentaire.shape[1]))
# Out:
# le tableau contient 15605 observation(s) ou article(s)
# le tableau contient 18 colonne(s)

# %%
display(dispo_alimentaire.head())
# Out:
#           Zone                Produit   Origine  Aliments pour animaux  \
# 0  Afghanistan       Abats Comestible   animale                    NaN
# 1  Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2  Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3  Afghanistan                 Ananas  vegetale                    NaN
# 4  Afghanistan                Bananes  vegetale                    NaN
#
#    Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                  NaN                                             5.0
# 1                  NaN                                             1.0
# 2                  NaN                                             1.0
# 3                  NaN                                             0.0
# 4                  NaN                                             4.0
#
#    Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                               1.72
# 1                                               1.29
# 2                                               0.06
# 3                                               0.00
# 4                                               2.70
#
#    Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                               0.20
# 1                                               0.01
# 2                                               0.01
# 3                                                NaN
# 4                                               0.02
#
#    Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                               0.77
# 1                                               0.02
# 2                                               0.03
# 3                                                NaN
# 4                                               0.05
#
#    Disponibilité intérieure  Exportations - Quantité  Importations - Quantité  \
# 0                      53.0                      NaN                      NaN
# 1                      41.0                      2.0                     40.0
# 2                       2.0                      NaN                      2.0
# 3                       0.0                      NaN                      0.0
# 4                      82.0                      NaN                     82.0
#
#    Nourriture  Pertes  Production  Semences  Traitement  Variation de stock
# 0        53.0     NaN        53.0       NaN         NaN                 NaN
# 1        39.0     2.0         3.0       NaN         NaN                 NaN
# 2         2.0     NaN         NaN       NaN         NaN                 NaN
# 3         0.0     NaN         NaN       NaN         NaN                 NaN
# 4        82.0     NaN         NaN       NaN         NaN                 NaN

# %%
#Renom de colonne
dispo_alimentaire.rename(columns = {'Zone': 'Pays bénéficiaire'})
# Out:
#       Pays bénéficiaire                Produit   Origine  \
# 0           Afghanistan       Abats Comestible   animale
# 1           Afghanistan        Agrumes, Autres  vegetale
# 2           Afghanistan  Aliments pour enfants  vegetale
# 3           Afghanistan                 Ananas  vegetale
# 4           Afghanistan                Bananes  vegetale
# ...                 ...                    ...       ...
# 15600      Îles Salomon       Viande de Suides   animale
# 15601      Îles Salomon    Viande de Volailles   animale
# 15602      Îles Salomon          Viande, Autre   animale
# 15603      Îles Salomon                    Vin  vegetale
# 15604      Îles Salomon         Épices, Autres  vegetale
#
#        Aliments pour animaux  Autres Utilisations  \
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 2                        NaN                  NaN
# 3                        NaN                  NaN
# 4                        NaN                  NaN
# ...                      ...                  ...
# 15600                    NaN                  NaN
# 15601                    NaN                  NaN
# 15602                    NaN                  NaN
# 15603                    NaN                  NaN
# 15604                    NaN                  NaN
#
#        Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                                 5.0
# 1                                                 1.0
# 2                                                 1.0
# 3                                                 0.0
# 4                                                 4.0
# ...                                               ...
# 15600                                            45.0
# 15601                                            11.0
# 15602                                             0.0
# 15603                                             0.0
# 15604                                             4.0
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                                   1.72
# 1                                                   1.29
# 2                                                   0.06
# 3                                                   0.00
# 4                                                   2.70
# ...                                                  ...
# 15600                                               4.70
# 15601                                               3.34
# 15602                                               0.06
# 15603                                               0.07
# 15604                                               0.48
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                                   0.20
# 1                                                   0.01
# 2                                                   0.01
# 3                                                    NaN
# 4                                                   0.02
# ...                                                  ...
# 15600                                               4.28
# 15601                                               0.69
# 15602                                                NaN
# 15603                                                NaN
# 15604                                               0.21
#
#        Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                                   0.77
# 1                                                   0.02
# 2                                                   0.03
# 3                                                    NaN
# 4                                                   0.05
# ...                                                  ...
# 15600                                               1.41
# 15601                                               1.14
# 15602                                               0.04
# 15603                                                NaN
# 15604                                               0.15
#
#        Disponibilité intérieure  Exportations - Quantité  \
# 0                          53.0                      NaN
# 1                          41.0                      2.0
# 2                           2.0                      NaN
# 3                           0.0                      NaN
# 4                          82.0                      NaN
# ...                         ...                      ...
# 15600                       3.0                      NaN
# 15601                       2.0                      NaN
# 15602                       0.0                      NaN
# 15603                       0.0                      0.0
# 15604                       0.0                      0.0
#
#        Importations - Quantité  Nourriture  Pertes  Production  Semences  \
# 0                          NaN        53.0     NaN        53.0       NaN
# 1                         40.0        39.0     2.0         3.0       NaN
# 2                          2.0         2.0     NaN         NaN       NaN
# 3                          0.0         0.0     NaN         NaN       NaN
# 4                         82.0        82.0     NaN         NaN       NaN
# ...                        ...         ...     ...         ...       ...
# 15600                      0.0         3.0     NaN         2.0       NaN
# 15601                      2.0         2.0     NaN         0.0       NaN
# 15602                      0.0         0.0     NaN         NaN       NaN
# 15603                      0.0         0.0     NaN         NaN       NaN
# 15604                      0.0         0.0     NaN         0.0       NaN
#
#        Traitement  Variation de stock
# 0             NaN                 NaN
# 1             NaN                 NaN
# 2             NaN                 NaN
# 3             NaN                 NaN
# 4             NaN                 NaN
# ...           ...                 ...
# 15600         NaN                 NaN
# 15601         NaN                 NaN
# 15602         NaN                 NaN
# 15603         NaN                 NaN
# 15604         NaN                 NaN
#
# [15605 rows x 18 columns]

# %%
print('le tableau contient {} observation(s) ou article(s)'.format(aide_alimentaire.shape[0]))
print('le tableau contient {} colonne(s)'.format(aide_alimentaire.shape[1]))
aide_alimentaire.rename(columns = {'Pays bénéficiaire': 'Zone'})
# Out:
# le tableau contient 1475 observation(s) ou article(s)
# le tableau contient 4 colonne(s)
#              Zone  Année                   Produit  Valeur
# 0     Afghanistan   2013       Autres non-céréales     682
# 1     Afghanistan   2014       Autres non-céréales     335
# 2     Afghanistan   2013              Blé et Farin   39224
# 3     Afghanistan   2014              Blé et Farin   15160
# 4     Afghanistan   2013                  Céréales   40504
# ...           ...    ...                       ...     ...
# 1470     Zimbabwe   2015  Mélanges et préparations      96
# 1471     Zimbabwe   2013              Non-céréales    5022
# 1472     Zimbabwe   2014              Non-céréales    2310
# 1473     Zimbabwe   2015              Non-céréales     306
# 1474     Zimbabwe   2013                Riz, total      64
#
# [1475 rows x 4 columns]

# %%
aide_alimentaire['Valeur'] = aide_alimentaire['Valeur']*1000
display(aide_alimentaire.head())
# Out:
#   Pays bénéficiaire  Année              Produit    Valeur
# 0       Afghanistan   2013  Autres non-céréales    682000
# 1       Afghanistan   2014  Autres non-céréales    335000
# 2       Afghanistan   2013         Blé et Farin  39224000
# 3       Afghanistan   2014         Blé et Farin  15160000
# 4       Afghanistan   2013             Céréales  40504000

# %%
print('le tableau contient {} observation(s) ou article(s)'.format(sous_nutrition.shape[0]))
print('le tableau contient {} colonne(s)'.format(sous_nutrition.shape[1]))
display(sous_nutrition.head())
# Out:
# le tableau contient 1218 observation(s) ou article(s)
# le tableau contient 3 colonne(s)
#           Zone      Année Valeur
# 0  Afghanistan  2012-2014    8.6
# 1  Afghanistan  2013-2015    8.8
# 2  Afghanistan  2014-2016    8.9
# 3  Afghanistan  2015-2017    9.7
# 4  Afghanistan  2016-2018   10.5

# %%
#Conversion de string en valeur numérique. Le dernier argument transforme les valeurs telles que <0.1 en valeur NULL
sous_nutrition['Valeur'] = pd.to_numeric(sous_nutrition['Valeur'], errors = 'coerce' )

# %%
#inplace permet de sauvegarder le changement, comme nous l'aurions fait en stockant le changement dans une variable

sous_nutrition.rename(columns = {'Valeur': 'Sous-nutrition'}, inplace = True)

# %%
display(sous_nutrition)
# Out:
#              Zone      Année  Sous-nutrition
# 0     Afghanistan  2012-2014             8.6
# 1     Afghanistan  2013-2015             8.8
# 2     Afghanistan  2014-2016             8.9
# 3     Afghanistan  2015-2017             9.7
# 4     Afghanistan  2016-2018            10.5
# ...           ...        ...             ...
# 1213     Zimbabwe  2013-2015             NaN
# 1214     Zimbabwe  2014-2016             NaN
# 1215     Zimbabwe  2015-2017             NaN
# 1216     Zimbabwe  2016-2018             NaN
# 1217     Zimbabwe  2017-2019             NaN
#
# [1218 rows x 3 columns]

# %%
#Conversion de la population, de millions à l'unité
sous_nutrition['Sous-nutrition'] =  sous_nutrition['Sous-nutrition'] *1000000

# %%
display(sous_nutrition.head())
# Out:
#           Zone      Année  Sous-nutrition
# 0  Afghanistan  2012-2014       8600000.0
# 1  Afghanistan  2013-2015       8800000.0
# 2  Afghanistan  2014-2016       8900000.0
# 3  Afghanistan  2015-2017       9700000.0
# 4  Afghanistan  2016-2018      10500000.0

# %%
#Création d'une variable ne gardant les données de population à l'année 2017
population_2017 = population.loc[population['Année']==2017, :]
display(population_2017)
# Out:
#                                         Zone  Année      Valeur
# 4                                Afghanistan   2017  36296113.0
# 10                            Afrique du Sud   2017  57009756.0
# 16                                   Albanie   2017   2884169.0
# 22                                   Algérie   2017  41389189.0
# 28                                 Allemagne   2017  82658409.0
# ...                                      ...    ...         ...
# 1390  Venezuela (République bolivarienne du)   2017  29402484.0
# 1396                                Viet Nam   2017  94600648.0
# 1402                                   Yémen   2017  27834819.0
# 1408                                  Zambie   2017  16853599.0
# 1414                                Zimbabwe   2017  14236595.0
#
# [236 rows x 3 columns]

# %%
#Idem, mais pour le document sous-nutrition
sous_nutrition_2017 = sous_nutrition.loc[sous_nutrition['Année']=='2016-2018', :]
display(sous_nutrition_2017)
# Out:
#                                         Zone      Année  Sous-nutrition
# 4                                Afghanistan  2016-2018      10500000.0
# 10                            Afrique du Sud  2016-2018       3100000.0
# 16                                   Albanie  2016-2018        100000.0
# 22                                   Algérie  2016-2018       1300000.0
# 28                                 Allemagne  2016-2018             NaN
# ...                                      ...        ...             ...
# 1192  Venezuela (République bolivarienne du)  2016-2018       8000000.0
# 1198                                Viet Nam  2016-2018       6500000.0
# 1204                                   Yémen  2016-2018             NaN
# 1210                                  Zambie  2016-2018             NaN
# 1216                                Zimbabwe  2016-2018             NaN
#
# [203 rows x 3 columns]

# %% [markdown]
# # Etude de la population mondiale en état de sous-nutrition

# %%
#Jointure des deux documents récemment créés, avec 'Zone' comme clé
population_sous_nutrition = pd.merge(population_2017, sous_nutrition_2017, on = 'Zone', how = 'right')
display(population_sous_nutrition)
# Out:
#                                        Zone  Année_x      Valeur    Année_y  \
# 0                               Afghanistan     2017  36296113.0  2016-2018
# 1                            Afrique du Sud     2017  57009756.0  2016-2018
# 2                                   Albanie     2017   2884169.0  2016-2018
# 3                                   Algérie     2017  41389189.0  2016-2018
# 4                                 Allemagne     2017  82658409.0  2016-2018
# ..                                      ...      ...         ...        ...
# 198  Venezuela (République bolivarienne du)     2017  29402484.0  2016-2018
# 199                                Viet Nam     2017  94600648.0  2016-2018
# 200                                   Yémen     2017  27834819.0  2016-2018
# 201                                  Zambie     2017  16853599.0  2016-2018
# 202                                Zimbabwe     2017  14236595.0  2016-2018
#
#      Sous-nutrition
# 0        10500000.0
# 1         3100000.0
# 2          100000.0
# 3         1300000.0
# 4               NaN
# ..              ...
# 198       8000000.0
# 199       6500000.0
# 200             NaN
# 201             NaN
# 202             NaN
#
# [203 rows x 5 columns]

# %%
#Calcul, pour chaque pays, du pourcentage local de la population en sous-nutrition
population_sous_nutrition['Pourcentage sous-nutrition'] = population_sous_nutrition['Sous-nutrition']*100/population_sous_nutrition['Valeur']
display(population_sous_nutrition)
#Calcul du pourcentage mondiale de la population en situation de sous-nutrition. On créé les sommes avant d'en calculer le ratio
proportion_mondiale = population_sous_nutrition['Sous-nutrition'].sum()*100/population_sous_nutrition['Valeur'].sum()
print(population_sous_nutrition['Valeur'].sum())
print(population_sous_nutrition['Sous-nutrition'].sum())
print(proportion_mondiale)
# Out:
#                                        Zone  Année_x      Valeur    Année_y  \
# 0                               Afghanistan     2017  36296113.0  2016-2018
# 1                            Afrique du Sud     2017  57009756.0  2016-2018
# 2                                   Albanie     2017   2884169.0  2016-2018
# 3                                   Algérie     2017  41389189.0  2016-2018
# 4                                 Allemagne     2017  82658409.0  2016-2018
# ..                                      ...      ...         ...        ...
# 198  Venezuela (République bolivarienne du)     2017  29402484.0  2016-2018
# 199                                Viet Nam     2017  94600648.0  2016-2018
# 200                                   Yémen     2017  27834819.0  2016-2018
# 201                                  Zambie     2017  16853599.0  2016-2018
# 202                                Zimbabwe     2017  14236595.0  2016-2018
#
#      Sous-nutrition  Pourcentage sous-nutrition
# 0        10500000.0                   28.928718
# 1         3100000.0                    5.437666
# 2          100000.0                    3.467203
# 3         1300000.0                    3.140917
# 4               NaN                         NaN
# ..              ...                         ...
# 198       8000000.0                   27.208586
# 199       6500000.0                    6.870989
# 200             NaN                         NaN
# 201             NaN                         NaN
# 202             NaN                         NaN
#
# [203 rows x 6 columns]
# 7543798779.0
# 535700000.0
# 7.1011968332354165

# %%
#Création de la variable de la quantité journalière de calories requises par personne
required_kcal = 2500

# %%
#Fusion des documents dispo_alimentaire et population, avec 'Zone' pour clé
data_dispo = pd.merge(dispo_alimentaire, population_2017, on = 'Zone')
display(data_dispo)
# Out:
#                Zone                Produit   Origine  Aliments pour animaux  \
# 0       Afghanistan       Abats Comestible   animale                    NaN
# 1       Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2       Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3       Afghanistan                 Ananas  vegetale                    NaN
# 4       Afghanistan                Bananes  vegetale                    NaN
# ...             ...                    ...       ...                    ...
# 15411  Îles Salomon       Viande de Suides   animale                    NaN
# 15412  Îles Salomon    Viande de Volailles   animale                    NaN
# 15413  Îles Salomon          Viande, Autre   animale                    NaN
# 15414  Îles Salomon                    Vin  vegetale                    NaN
# 15415  Îles Salomon         Épices, Autres  vegetale                    NaN
#
#        Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                      NaN                                             5.0
# 1                      NaN                                             1.0
# 2                      NaN                                             1.0
# 3                      NaN                                             0.0
# 4                      NaN                                             4.0
# ...                    ...                                             ...
# 15411                  NaN                                            45.0
# 15412                  NaN                                            11.0
# 15413                  NaN                                             0.0
# 15414                  NaN                                             0.0
# 15415                  NaN                                             4.0
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                                   1.72
# 1                                                   1.29
# 2                                                   0.06
# 3                                                   0.00
# 4                                                   2.70
# ...                                                  ...
# 15411                                               4.70
# 15412                                               3.34
# 15413                                               0.06
# 15414                                               0.07
# 15415                                               0.48
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                                   0.20
# 1                                                   0.01
# 2                                                   0.01
# 3                                                    NaN
# 4                                                   0.02
# ...                                                  ...
# 15411                                               4.28
# 15412                                               0.69
# 15413                                                NaN
# 15414                                                NaN
# 15415                                               0.21
#
#        Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                                   0.77
# 1                                                   0.02
# 2                                                   0.03
# 3                                                    NaN
# 4                                                   0.05
# ...                                                  ...
# 15411                                               1.41
# 15412                                               1.14
# 15413                                               0.04
# 15414                                                NaN
# 15415                                               0.15
#
#        Disponibilité intérieure  Exportations - Quantité  \
# 0                          53.0                      NaN
# 1                          41.0                      2.0
# 2                           2.0                      NaN
# 3                           0.0                      NaN
# 4                          82.0                      NaN
# ...                         ...                      ...
# 15411                       3.0                      NaN
# 15412                       2.0                      NaN
# 15413                       0.0                      NaN
# 15414                       0.0                      0.0
# 15415                       0.0                      0.0
#
#        Importations - Quantité  Nourriture  Pertes  Production  Semences  \
# 0                          NaN        53.0     NaN        53.0       NaN
# 1                         40.0        39.0     2.0         3.0       NaN
# 2                          2.0         2.0     NaN         NaN       NaN
# 3                          0.0         0.0     NaN         NaN       NaN
# 4                         82.0        82.0     NaN         NaN       NaN
# ...                        ...         ...     ...         ...       ...
# 15411                      0.0         3.0     NaN         2.0       NaN
# 15412                      2.0         2.0     NaN         0.0       NaN
# 15413                      0.0         0.0     NaN         NaN       NaN
# 15414                      0.0         0.0     NaN         NaN       NaN
# 15415                      0.0         0.0     NaN         0.0       NaN
#
#        Traitement  Variation de stock  Année      Valeur
# 0             NaN                 NaN   2017  36296113.0
# 1             NaN                 NaN   2017  36296113.0
# 2             NaN                 NaN   2017  36296113.0
# 3             NaN                 NaN   2017  36296113.0
# 4             NaN                 NaN   2017  36296113.0
# ...           ...                 ...    ...         ...
# 15411         NaN                 NaN   2017    636039.0
# 15412         NaN                 NaN   2017    636039.0
# 15413         NaN                 NaN   2017    636039.0
# 15414         NaN                 NaN   2017    636039.0
# 15415         NaN                 NaN   2017    636039.0
#
# [15416 rows x 20 columns]

# %%
#produit des disponibilités alimentaire par personne, par population locale afin d'avoir, par pays, la dispo alimentaire totale
data_dispo['dispo_kcal(kcal/j)'] = data_dispo['Disponibilité alimentaire (Kcal/personne/jour)']*data_dispo['Valeur']

# %%
display(data_dispo)
# Out:
#                Zone                Produit   Origine  Aliments pour animaux  \
# 0       Afghanistan       Abats Comestible   animale                    NaN
# 1       Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2       Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3       Afghanistan                 Ananas  vegetale                    NaN
# 4       Afghanistan                Bananes  vegetale                    NaN
# ...             ...                    ...       ...                    ...
# 15411  Îles Salomon       Viande de Suides   animale                    NaN
# 15412  Îles Salomon    Viande de Volailles   animale                    NaN
# 15413  Îles Salomon          Viande, Autre   animale                    NaN
# 15414  Îles Salomon                    Vin  vegetale                    NaN
# 15415  Îles Salomon         Épices, Autres  vegetale                    NaN
#
#        Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                      NaN                                             5.0
# 1                      NaN                                             1.0
# 2                      NaN                                             1.0
# 3                      NaN                                             0.0
# 4                      NaN                                             4.0
# ...                    ...                                             ...
# 15411                  NaN                                            45.0
# 15412                  NaN                                            11.0
# 15413                  NaN                                             0.0
# 15414                  NaN                                             0.0
# 15415                  NaN                                             4.0
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# 0                                                   1.72
# 1                                                   1.29
# 2                                                   0.06
# 3                                                   0.00
# 4                                                   2.70
# ...                                                  ...
# 15411                                               4.70
# 15412                                               3.34
# 15413                                               0.06
# 15414                                               0.07
# 15415                                               0.48
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 0                                                   0.20
# 1                                                   0.01
# 2                                                   0.01
# 3                                                    NaN
# 4                                                   0.02
# ...                                                  ...
# 15411                                               4.28
# 15412                                               0.69
# 15413                                                NaN
# 15414                                                NaN
# 15415                                               0.21
#
#        Disponibilité de protéines en quantité (g/personne/jour)  \
# 0                                                   0.77
# 1                                                   0.02
# 2                                                   0.03
# 3                                                    NaN
# 4                                                   0.05
# ...                                                  ...
# 15411                                               1.41
# 15412                                               1.14
# 15413                                               0.04
# 15414                                                NaN
# 15415                                               0.15
#
#        Disponibilité intérieure  ...  Importations - Quantité  Nourriture  \
# 0                          53.0  ...                      NaN        53.0
# 1                          41.0  ...                     40.0        39.0
# 2                           2.0  ...                      2.0         2.0
# 3                           0.0  ...                      0.0         0.0
# 4                          82.0  ...                     82.0        82.0
# ...                         ...  ...                      ...         ...
# 15411                       3.0  ...                      0.0         3.0
# 15412                       2.0  ...                      2.0         2.0
# 15413                       0.0  ...                      0.0         0.0
# 15414                       0.0  ...                      0.0         0.0
# 15415                       0.0  ...                      0.0         0.0
#
#        Pertes  Production  Semences  Traitement  Variation de stock  Année  \
# 0         NaN        53.0       NaN         NaN                 NaN   2017
# 1         2.0         3.0       NaN         NaN                 NaN   2017
# 2         NaN         NaN       NaN         NaN                 NaN   2017
# 3         NaN         NaN       NaN         NaN                 NaN   2017
# 4         NaN         NaN       NaN         NaN                 NaN   2017
# ...       ...         ...       ...         ...                 ...    ...
# 15411     NaN         2.0       NaN         NaN                 NaN   2017
# 15412     NaN         0.0       NaN         NaN                 NaN   2017
# 15413     NaN         NaN       NaN         NaN                 NaN   2017
# 15414     NaN         NaN       NaN         NaN                 NaN   2017
# 15415     NaN         0.0       NaN         NaN                 NaN   2017
#
#            Valeur  dispo_kcal(kcal/j)
# 0      36296113.0         181480565.0
# 1      36296113.0          36296113.0
# 2      36296113.0          36296113.0
# 3      36296113.0                 0.0
# 4      36296113.0         145184452.0
# ...           ...                 ...
# 15411    636039.0          28621755.0
# 15412    636039.0           6996429.0
# 15413    636039.0                 0.0
# 15414    636039.0                 0.0
# 15415    636039.0           2544156.0
#
# [15416 rows x 21 columns]

# %%
#Obtention de la dispo alimenraire totale
somme = data_dispo['dispo_kcal(kcal/j)'].sum()

# %%
print(somme)
# Out:
# 20918984627331.0

# %%
#Division par la quantité journalière requise, et affichage en milliards d'habitants
milliards_hab = somme/required_kcal/1000000000
print(milliards_hab)
# Out:
# 8.3675938509324

# %% [markdown]
# # Etude de la population pouvant théoriquement être nourrie avec des végétaux

# %%
#création d'une base de données ne gardant que les produits d'origine végétale
data_dispo_veg = data_dispo.loc[data_dispo['Origine']=='vegetale', :]

# %%
display(data_dispo_veg.head(10))
# Out:
#            Zone                Produit   Origine  Aliments pour animaux  \
# 1   Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2   Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3   Afghanistan                 Ananas  vegetale                    NaN
# 4   Afghanistan                Bananes  vegetale                    NaN
# 6   Afghanistan                  Bière  vegetale                    NaN
# 7   Afghanistan                    Blé  vegetale                    NaN
# 8   Afghanistan   Boissons Alcooliques  vegetale                    NaN
# 9   Afghanistan                   Café  vegetale                    NaN
# 10  Afghanistan     Coco (Incl Coprah)  vegetale                    NaN
# 12  Afghanistan       Céréales, Autres  vegetale                    NaN
#
#     Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 1                   NaN                                             1.0
# 2                   NaN                                             1.0
# 3                   NaN                                             0.0
# 4                   NaN                                             4.0
# 6                   NaN                                             0.0
# 7                   NaN                                          1369.0
# 8                   NaN                                             0.0
# 9                   NaN                                             0.0
# 10                  NaN                                             0.0
# 12                  NaN                                             0.0
#
#     Disponibilité alimentaire en quantité (kg/personne/an)  \
# 1                                                1.29
# 2                                                0.06
# 3                                                0.00
# 4                                                2.70
# 6                                                0.09
# 7                                              160.23
# 8                                                0.00
# 9                                                0.00
# 10                                               0.00
# 12                                               0.00
#
#     Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 1                                                0.01
# 2                                                0.01
# 3                                                 NaN
# 4                                                0.02
# 6                                                 NaN
# 7                                                4.69
# 8                                                 NaN
# 9                                                 NaN
# 10                                               0.00
# 12                                               0.00
#
#     Disponibilité de protéines en quantité (g/personne/jour)  \
# 1                                                0.02
# 2                                                0.03
# 3                                                 NaN
# 4                                                0.05
# 6                                                0.00
# 7                                               36.91
# 8                                                 NaN
# 9                                                0.00
# 10                                               0.00
# 12                                               0.00
#
#     Disponibilité intérieure  ...  Importations - Quantité  Nourriture  \
# 1                       41.0  ...                     40.0        39.0
# 2                        2.0  ...                      2.0         2.0
# 3                        0.0  ...                      0.0         0.0
# 4                       82.0  ...                     82.0        82.0
# 6                        3.0  ...                      3.0         3.0
# 7                     5992.0  ...                   1173.0      4895.0
# 8                        0.0  ...                      0.0         0.0
# 9                        0.0  ...                      0.0         0.0
# 10                       0.0  ...                      0.0         0.0
# 12                       0.0  ...                      0.0         0.0
#
#     Pertes  Production  Semences  Traitement  Variation de stock  Année  \
# 1      2.0         3.0       NaN         NaN                 NaN   2017
# 2      NaN         NaN       NaN         NaN                 NaN   2017
# 3      NaN         NaN       NaN         NaN                 NaN   2017
# 4      NaN         NaN       NaN         NaN                 NaN   2017
# 6      NaN         NaN       NaN         NaN                 NaN   2017
# 7    775.0      5169.0     322.0         NaN              -350.0   2017
# 8      NaN         NaN       NaN         NaN                 NaN   2017
# 9      NaN         NaN       NaN         NaN                 NaN   2017
# 10     NaN         NaN       NaN         NaN                 NaN   2017
# 12     NaN         NaN       NaN         NaN                 NaN   2017
#
#         Valeur  dispo_kcal(kcal/j)
# 1   36296113.0        3.629611e+07
# 2   36296113.0        3.629611e+07
# 3   36296113.0        0.000000e+00
# 4   36296113.0        1.451845e+08
# 6   36296113.0        0.000000e+00
# 7   36296113.0        4.968938e+10
# 8   36296113.0        0.000000e+00
# 9   36296113.0        0.000000e+00
# 10  36296113.0        0.000000e+00
# 12  36296113.0        0.000000e+00
#
# [10 rows x 21 columns]

# %%
#Même calculs que précédemment, mais sur la nouvelle base de données
veg_dispo = data_dispo_veg['dispo_kcal(kcal/j)'].sum()
print(veg_dispo)
#Nombre d'habitants pouvant théoriquement être nourris avec des aliments d'origine végétale
sum_hab_veg_milliards = veg_dispo/required_kcal/1000000000
print(sum_hab_veg_milliards)
# Out:
# 17260764211501.0
# 6.9043056846004

# %%
dispo_totale = dispo_alimentaire['Disponibilité intérieure'].sum()
print(dispo_totale)
# Out:
# 9848994.0

# %% [markdown]
# # Part d'utilisation de la nourriture dans le monde

# %%
#Création de variables totalisant les utilisations respectives des utilisations de nourriture
Animaux = dispo_alimentaire['Aliments pour animaux'].sum()
Autres = dispo_alimentaire['Autres Utilisations'].sum()
Nourriture = dispo_alimentaire['Nourriture'].sum()
Pertes = dispo_alimentaire['Pertes'].sum()
Semences = dispo_alimentaire['Semences'].sum()
Traitement = dispo_alimentaire['Traitement'].sum()

# %%
#Création d'un tableau via Numpy pour faciliter le traçage d'un graphique
import numpy as np
import matplotlib.pyplot as plt
totaux_int = np.array([['Animaux', Animaux], ['Autres', Autres], ['Nourriture', Nourriture], ['Pertes', Pertes], ['Traitement', Traitement], ['Semences', Semences]])
print(totaux_int)
# Out:
# [['Animaux' '1304245.0']
#  ['Autres' '865023.0']
#  ['Nourriture' '4876258.0']
#  ['Pertes' '453698.0']
#  ['Traitement' '2204687.0']
#  ['Semences' '154681.0']]

# %%
#Répartition de la disponibilité intérieure mondiale
sns.set_theme(rc={'figure.figsize':(12,8)})
plt.pie(x=totaux_int[:, 1], labels=totaux_int[:, 0], autopct='%.2f%%')
plt.title('Répartition de la disponibilité intérieure mondiale')
plt.show()

# %%
#Création de variables totalisant les utilisations respectives des utilisations de nourriture
Production = dispo_alimentaire['Production'].sum()
Imports = dispo_alimentaire['Importations - Quantité'].sum()
Exports = dispo_alimentaire['Exportations - Quantité'].sum()
Variations = dispo_alimentaire['Variation de stock'].sum()

Transferts = np.array([['Production', Production], ['Importations - Quantité', Imports], ['Exportations - Quantité', Exports], ['Variation de stock', np.abs(Variations)]])
print(Transferts)

sns.set_theme(rc={'figure.figsize':(8,8)})
plt.pie(x=Transferts[:, 1], labels=Transferts[:, 0], autopct='%.2f%%')
plt.title('Répartition de la disponibilité intérieure mondiale')
plt.show()
# Out:
# [['Production' '10009680.0']
#  ['Importations - Quantité' '1296053.0']
#  ['Exportations - Quantité' '1352158.0']
#  ['Variation de stock' '104402.0']]

# %% [markdown]
# # Etude de l'utilisation des céréales dans le monde

# %%
#Création d'une liste contenant l'ensemble des types de céréales mentionnées dans le document dispo_alimentaire
liste_cereales = ['Blé', 'Riz (Eq Blanchi)', 'Orge', 'Maïs', 'Seigle', 'Avoine',
                  'Millet', 'Sorgho', 'Céréales, Autres']

# %%
#Création d'une base de données ne gardant que les produits de type céréale
df_tri = []
for i in liste_cereales:
    df_tri.append(dispo_alimentaire.loc[dispo_alimentaire['Produit']==i,:])
data_cereales = pd.concat(df_tri)
display(data_cereales)
# Out:
#                         Zone           Produit   Origine  \
# 7                Afghanistan               Blé  vegetale
# 72            Afrique du Sud               Blé  vegetale
# 167                  Albanie               Blé  vegetale
# 259                  Algérie               Blé  vegetale
# 352                Allemagne               Blé  vegetale
# ...                      ...               ...       ...
# 15173    Émirats arabes unis  Céréales, Autres  vegetale
# 15266               Équateur  Céréales, Autres  vegetale
# 15361  États-Unis d'Amérique  Céréales, Autres  vegetale
# 15454               Éthiopie  Céréales, Autres  vegetale
# 15545           Îles Salomon  Céréales, Autres  vegetale
#
#        Aliments pour animaux  Autres Utilisations  \
# 7                        NaN                  NaN
# 72                      37.0                  NaN
# 167                     18.0                130.0
# 259                    545.0                820.0
# 352                   7494.0                774.0
# ...                      ...                  ...
# 15173                    1.0                  1.0
# 15266                    1.0                  NaN
# 15361                   77.0                  NaN
# 15454                    0.0                469.0
# 15545                    NaN                  NaN
#
#        Disponibilité alimentaire (Kcal/personne/jour)  \
# 7                                              1369.0
# 72                                              492.0
# 167                                            1056.0
# 259                                            1424.0
# 352                                             654.0
# ...                                               ...
# 15173                                             0.0
# 15266                                             0.0
# 15361                                             5.0
# 15454                                           254.0
# 15545                                             0.0
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# 7                                                 160.23
# 72                                                 60.13
# 167                                               138.64
# 259                                               185.42
# 352                                                83.41
# ...                                                  ...
# 15173                                               0.00
# 15266                                               0.05
# 15361                                               0.62
# 15454                                              26.52
# 15545                                               0.00
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 7                                                   4.69
# 72                                                  2.09
# 167                                                 5.85
# 259                                                 5.34
# 352                                                 2.59
# ...                                                  ...
# 15173                                               0.00
# 15266                                               0.01
# 15361                                               0.02
# 15454                                               0.77
# 15545                                               0.00
#
#        Disponibilité de protéines en quantité (g/personne/jour)  \
# 7                                                  36.91
# 72                                                 15.40
# 167                                                33.64
# 259                                                42.97
# 352                                                21.17
# ...                                                  ...
# 15173                                               0.00
# 15266                                               0.02
# 15361                                               0.15
# 15454                                               6.97
# 15545                                               0.00
#
#        Disponibilité intérieure  Exportations - Quantité  \
# 7                        5992.0                      NaN
# 72                       3316.0                    495.0
# 167                       650.0                      4.0
# 259                      9461.0                      2.0
# 352                     16491.0                  10870.0
# ...                         ...                      ...
# 15173                     -40.0                     59.0
# 15266                       2.0                      1.0
# 15361                     271.0                     91.0
# 15454                    3274.0                      0.0
# 15545                       0.0                      NaN
#
#        Importations - Quantité  Nourriture  Pertes  Production  Semences  \
# 7                       1173.0      4895.0   775.0      5169.0     322.0
# 72                      1490.0      3174.0    74.0      1870.0      31.0
# 167                      360.0       440.0    44.0       294.0      18.0
# 259                     6343.0      7270.0   672.0      3299.0     153.0
# 352                     5421.0      6900.0   663.0     25019.0     571.0
# ...                        ...         ...     ...         ...       ...
# 15173                     21.0         0.0     0.0         NaN       NaN
# 15266                      2.0         1.0     0.0         1.0       0.0
# 15361                    281.0       200.0     NaN        81.0       3.0
# 15454                      2.0      2495.0   234.0      4672.0      76.0
# 15545                      0.0         0.0     0.0         NaN       NaN
#
#        Traitement  Variation de stock
# 7             NaN              -350.0
# 72            0.0               450.0
# 167           NaN                 0.0
# 259           0.0              -180.0
# 352          90.0             -3079.0
# ...           ...                 ...
# 15173         NaN                -1.0
# 15266         NaN                 0.0
# 15361         NaN                 0.0
# 15454         NaN             -1400.0
# 15545         NaN                 NaN
#
# [1497 rows x 18 columns]

# %%
#Mise à jour de la base de données, ne conservant que les utilisation céréalières pour de la nourriture humaine et animale
part_cereales = data_cereales.groupby('Produit')[['Nourriture', 'Aliments pour animaux']].sum()
part_cereales = part_cereales.reset_index()

# %%
#Création des valeurs de quantité et pourcentage pour les deux catégories
part_cereales['Total'] = part_cereales['Nourriture'] + part_cereales['Aliments pour animaux']
part_cereales['Part Alimentation humaine (%)'] = round(part_cereales['Nourriture']*100 /part_cereales['Total'],2)
part_cereales['Part Alimentation pour animaux (%)'] = round(part_cereales['Aliments pour animaux']*100 /part_cereales['Total'], 2)

# %%
display(part_cereales)
# Out:
#             Produit  Nourriture  Aliments pour animaux     Total  \
# 0            Avoine      3903.0                16251.0   20154.0
# 1               Blé    457824.0               129668.0  587492.0
# 2  Céréales, Autres      5324.0                19035.0   24359.0
# 3              Maïs    125184.0               546116.0  671300.0
# 4            Millet     23040.0                 3306.0   26346.0
# 5              Orge      6794.0                92658.0   99452.0
# 6  Riz (Eq Blanchi)    377286.0                33594.0  410880.0
# 7            Seigle      5502.0                 8099.0   13601.0
# 8            Sorgho     24153.0                24808.0   48961.0
#
#    Part Alimentation humaine (%)  Part Alimentation pour animaux (%)
# 0                          19.37                               80.63
# 1                          77.93                               22.07
# 2                          21.86                               78.14
# 3                          18.65                               81.35
# 4                          87.45                               12.55
# 5                           6.83                               93.17
# 6                          91.82                                8.18
# 7                          40.45                               59.55
# 8                          49.33                               50.67

# %%
#Formatage de la base de donnée pour faciliter la création d'un graphique
part_cereales = part_cereales.melt(id_vars = 'Produit', value_vars = ['Nourriture', 'Aliments pour animaux'])
display(part_cereales)
# Out:
#              Produit               variable     value
# 0             Avoine             Nourriture    3903.0
# 1                Blé             Nourriture  457824.0
# 2   Céréales, Autres             Nourriture    5324.0
# 3               Maïs             Nourriture  125184.0
# 4             Millet             Nourriture   23040.0
# 5               Orge             Nourriture    6794.0
# 6   Riz (Eq Blanchi)             Nourriture  377286.0
# 7             Seigle             Nourriture    5502.0
# 8             Sorgho             Nourriture   24153.0
# 9             Avoine  Aliments pour animaux   16251.0
# 10               Blé  Aliments pour animaux  129668.0
# 11  Céréales, Autres  Aliments pour animaux   19035.0
# 12              Maïs  Aliments pour animaux  546116.0
# 13            Millet  Aliments pour animaux    3306.0
# 14              Orge  Aliments pour animaux   92658.0
# 15  Riz (Eq Blanchi)  Aliments pour animaux   33594.0
# 16            Seigle  Aliments pour animaux    8099.0
# 17            Sorgho  Aliments pour animaux   24808.0

# %%
#Création du graphique d'utilisation des céréales
import seaborn as sns
#On retire le style Seaborn défini précédemment pour que celui-ci n'interfère pas avec nos futurs graphiques
sns.reset_defaults()
sns.set_theme(rc={'figure.figsize':(12,8)})
ax = sns.barplot(data=part_cereales, x='Produit', y='value', ci=None, hue='variable')
for cont in ax.containers:
    ax.bar_label(cont, fontsize = 8)
plt.legend(title='Utilisation')
plt.ylabel('Quantité en millier de tonnes', fontsize = 18)
plt.xlabel('Type de céréale', fontsize = 18)
plt.show()
# Out:
# C:\Users\agall\AppData\Local\Temp\ipykernel_33244\2589117029.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(data=part_cereales, x='Produit', y='value', ci=None, hue='variable')

# %% [markdown]
# # Sélection des 10 pays étant le plus en état de sous-nutrition

# %%
#Tri décroissant de la population en état de sous-nutrition par pays
tri = population_sous_nutrition.sort_values(['Pourcentage sous-nutrition'], ascending = False)
#10 premières valeurs
tri2 = tri.head(10)
tri2 = tri2.reset_index()
#Changement de nom de République Démocratique de Corée, pour que le nom ne se superpose pas avec d'autres noms ou données
tri2.loc[1, 'Zone'] ='DRPK'
display(tri2)
# Out:
#    index         Zone  Année_x      Valeur    Année_y  Sous-nutrition  \
# 0     78        Haïti     2017  10982366.0  2016-2018       5300000.0
# 1    157         DRPK     2017  25429825.0  2016-2018      12000000.0
# 2    108   Madagascar     2017  25570512.0  2016-2018      10500000.0
# 3    103      Libéria     2017   4702226.0  2016-2018       1800000.0
# 4    100      Lesotho     2017   2091534.0  2016-2018        800000.0
# 5    183        Tchad     2017  15016753.0  2016-2018       5700000.0
# 6    161       Rwanda     2017  11980961.0  2016-2018       4200000.0
# 7    121   Mozambique     2017  28649018.0  2016-2018       9400000.0
# 8    186  Timor-Leste     2017   1243258.0  2016-2018        400000.0
# 9      0  Afghanistan     2017  36296113.0  2016-2018      10500000.0
#
#    Pourcentage sous-nutrition
# 0                   48.259182
# 1                   47.188685
# 2                   41.062924
# 3                   38.279742
# 4                   38.249438
# 5                   37.957606
# 6                   35.055619
# 7                   32.810898
# 8                   32.173531
# 9                   28.928718

# %%
#Création du graphique correspondant
#On retire le style Seaborn défini précédemment pour que celui-ci n'interfère pas avec nos futurs graphiques
sns.reset_defaults()

plt.figure(figsize = (14, 6))
plt.bar(height = tri2['Pourcentage sous-nutrition'], x = tri2['Zone'])
plt.title('Pourcentage de la population en situation de sous-nutrition', fontsize = 20)
plt.xlabel('Pays', fontsize = 18)
plt.ylabel('Pourcentage de la population', fontsize = 16)
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# # Etude des 10 pays ayant le plus bénéficié de l'aide alimentaire

# %%
#Somme des valeurs de l'aide alimentaire reçue entre 2013 et 2016
aide_2013_2016 = aide_alimentaire.groupby('Pays bénéficiaire').agg({'Valeur': 'sum'})
display(aide_2013_2016)
# Out:
#                        Valeur
# Pays bénéficiaire
# Afghanistan         185452000
# Algérie              81114000
# Angola                5014000
# Bangladesh          348188000
# Bhoutan               2666000
# ...                       ...
# Zambie                3026000
# Zimbabwe             62570000
# Égypte                1122000
# Équateur              1362000
# Éthiopie           1381294000
#
# [76 rows x 1 columns]

# %%
#On ne garde que les 10  premières lignes
tri_final = aide_2013_2016.sort_values('Valeur', ascending = False).head(10)
tri_final = tri_final.reset_index()

#Renom des pays au nom trop long, pour éviter la juxtaposition
tri_final.loc[0, 'Pays bénéficiaire'] ='Syrie'
tri_final.loc[8, 'Pays bénéficiaire'] ='Congo'
display(tri_final)

#Traçage du graphique
plt.figure(figsize = (14, 6))
plt.bar(height = tri_final['Valeur']/1000000, x = tri_final['Pays bénéficiaire'])
plt.title('Aide alimentaire reçue entre 2013 et 2016, pour les 10 pays en ayant le plus bénéficié', fontsize = 18)
plt.xlabel('Pays', fontsize = 18)
plt.ylabel('Aide reçue, en millions de tonnes', fontsize = 18)
plt.grid(axis = 'y')
plt.show()
# Out:
#   Pays bénéficiaire      Valeur
# 0             Syrie  1858943000
# 1          Éthiopie  1381294000
# 2             Yémen  1206484000
# 3     Soudan du Sud   695248000
# 4            Soudan   669784000
# 5             Kenya   552836000
# 6        Bangladesh   348188000
# 7           Somalie   292678000
# 8             Congo   288502000
# 9             Niger   276344000

# %% [markdown]
# # Evolution des 5 pays ayant le plus réceptionné d'aide alimentaire entre 2013 et 2016

# %%
df_aide_pays_annee =aide_alimentaire.groupby(['Pays bénéficiaire', 'Année']).agg({'Valeur': 'sum'})
df_aide_pays_annee = df_aide_pays_annee.reset_index()
display(df_aide_pays_annee )
# Out:
#     Pays bénéficiaire  Année     Valeur
# 0         Afghanistan   2013  128238000
# 1         Afghanistan   2014   57214000
# 2             Algérie   2013   35234000
# 3             Algérie   2014   18980000
# 4             Algérie   2015   17424000
# ..                ...    ...        ...
# 223            Égypte   2013    1122000
# 224          Équateur   2013    1362000
# 225          Éthiopie   2013  591404000
# 226          Éthiopie   2014  586624000
# 227          Éthiopie   2015  203266000
#
# [228 rows x 3 columns]

# %%
#Sélection des 5 pays ayant le plus bénéficié de l'aide alimentaire
tri_final = aide_2013_2016.sort_values('Valeur', ascending = False).head(10)
tri_final = tri_final.reset_index()
top_5 = tri_final.head(5)
#Fusion de base de données, afin d'inclure les années de réception de l'aide alimentaire
top_5_annee = pd.merge(top_5, df_aide_pays_annee, on = 'Pays bénéficiaire')
display(top_5_annee)
# Out:
#             Pays bénéficiaire    Valeur_x  Année   Valeur_y
# 0   République arabe syrienne  1858943000   2013  563566000
# 1   République arabe syrienne  1858943000   2014  651870000
# 2   République arabe syrienne  1858943000   2015  524949000
# 3   République arabe syrienne  1858943000   2016  118558000
# 4                    Éthiopie  1381294000   2013  591404000
# 5                    Éthiopie  1381294000   2014  586624000
# 6                    Éthiopie  1381294000   2015  203266000
# 7                       Yémen  1206484000   2013  264764000
# 8                       Yémen  1206484000   2014  103840000
# 9                       Yémen  1206484000   2015  372306000
# 10                      Yémen  1206484000   2016  465574000
# 11              Soudan du Sud   695248000   2013  196330000
# 12              Soudan du Sud   695248000   2014  450610000
# 13              Soudan du Sud   695248000   2015   48308000
# 14                     Soudan   669784000   2013  330230000
# 15                     Soudan   669784000   2014  321904000
# 16                     Soudan   669784000   2015   17650000

# %%
#Traçage du graphique correspondant

plt.figure(figsize = (11, 8))
for pays in top_5_annee['Pays bénéficiaire'].unique():
    df = top_5_annee.loc[top_5_annee['Pays bénéficiaire']==pays, :]
    plt.plot(df['Année'], df['Valeur_y']/1000, '-o', label = pays)
plt.legend()
plt.title('Evolution de alimentaire reçue par année', fontsize = 20)
plt.xticks([2013, 2014, 2015, 2016])
plt.xlabel('Année', fontsize = 18)
plt.ylabel('Aide alimentaire reçue, en millier de tonnes', fontsize = 18)
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# # 10 pays ayant la plus faible disposition alimentaire

# %%
#Calcul des pays ayant le plus faible disposition alimentaire

tri_disp_alimentaire = dispo_alimentaire.groupby('Zone').agg({'Disponibilité alimentaire (Kcal/personne/jour)': 'sum'})
tri_disp_alimentaire = tri_disp_alimentaire.sort_values('Disponibilité alimentaire (Kcal/personne/jour)').head(10)
tri_disp_alimentaire = tri_disp_alimentaire.reset_index()

#Renom des pays ayant un nom trop long
tri_disp_alimentaire.loc[0, 'Zone'] ='Rep. centrafricaine'
tri_disp_alimentaire.loc[5, 'Zone'] ='DRPK'
display(tri_disp_alimentaire)
# Out:
#                   Zone  Disponibilité alimentaire (Kcal/personne/jour)
# 0  Rep. centrafricaine                                          1879.0
# 1               Zambie                                          1924.0
# 2           Madagascar                                          2056.0
# 3          Afghanistan                                          2087.0
# 4                Haïti                                          2089.0
# 5                 DRPK                                          2093.0
# 6                Tchad                                          2109.0
# 7             Zimbabwe                                          2113.0
# 8              Ouganda                                          2126.0
# 9             Éthiopie                                          2129.0

# %%
#Traçage du graphique
plt.figure(figsize = (14, 6))
plt.bar(height = tri_disp_alimentaire['Disponibilité alimentaire (Kcal/personne/jour)'], x = tri_disp_alimentaire['Zone'], color = 'green')
plt.title('Liste des 10 pays ayant la plus faible disponibilité alimentaire', fontsize = 18)
plt.xlabel('Pays', fontsize = 18)
plt.ylabel('Disponibilité alimentaire (Kcal/personne/jour)', fontsize = 16)
plt.yticks([500, 1000, 1500, 2000, 2500, 3000, 3500])
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# # 10 pays ayant la plus forte disposition alimentaire

# %%
#Même calcul que précedemment, mais avec un tri décroissant
tri_disp_alimentaire_2 = dispo_alimentaire.groupby('Zone').agg({'Disponibilité alimentaire (Kcal/personne/jour)': 'sum'})
top10 = tri_disp_alimentaire_2.sort_values('Disponibilité alimentaire (Kcal/personne/jour)', ascending = False).head(10)
top10 = top10.reset_index()
top10.loc[3, "Zone"] = 'USA'
display(top10)
# Out:
#          Zone  Disponibilité alimentaire (Kcal/personne/jour)
# 0    Autriche                                          3770.0
# 1    Belgique                                          3737.0
# 2     Turquie                                          3708.0
# 3         USA                                          3682.0
# 4      Israël                                          3610.0
# 5     Irlande                                          3602.0
# 6      Italie                                          3578.0
# 7  Luxembourg                                          3540.0
# 8      Égypte                                          3518.0
# 9   Allemagne                                          3503.0

# %%
#Traçage du graphique
plt.figure(figsize = (14, 6))
plt.bar(height = top10['Disponibilité alimentaire (Kcal/personne/jour)'], x = top10['Zone'], color = 'burlywood')
plt.title('Liste des 10 pays ayant la plus forte disponibilité alimentaire', fontsize = 18)
plt.xlabel('Pays', fontsize = 18)
plt.ylabel('Disponibilité alimentaire (Kcal/personne/jour)', fontsize = 16)
plt.grid(axis = 'y')
plt.show()

# %% [markdown]
# # Etude sur le manioc en Thaïlande

# %%
#Etude de la sous-nutrition en Thaïlande, année après année

ss_nut_thai = sous_nutrition.loc[sous_nutrition['Zone']=='Thaïlande', :]
ss_nut_thai = ss_nut_thai.reset_index()
pop_thai = population.loc[population['Zone']=='Thaïlande', :]
ss_nut_thai.loc[0, 'Année'] =2013
ss_nut_thai.loc[1, 'Année'] =2014
ss_nut_thai.loc[2, 'Année'] =2015
ss_nut_thai.loc[3, 'Année'] =2016
ss_nut_thai.loc[4, 'Année'] =2017
ss_nut_thai.loc[5, 'Année'] =2018
display(ss_nut_thai)
# Out:
#    index       Zone Année  Sous-nutrition
# 0   1110  Thaïlande  2013       6200000.0
# 1   1111  Thaïlande  2014       6000000.0
# 2   1112  Thaïlande  2015       5900000.0
# 3   1113  Thaïlande  2016       6000000.0
# 4   1114  Thaïlande  2017       6200000.0
# 5   1115  Thaïlande  2018       6500000.0

# %%
#Fusion de la base de donnée précédente avec celle de la population année par année
df_thai = pd.merge(ss_nut_thai, pop_thai, on = ['Année', 'Zone'], how = 'left')

# %%
df_thai = df_thai.rename(columns={'Valeur':'Population totale'})

# %%
#Calcul du pourcentage de la population en sous-alimentation en Thaïlande
df_thai['Pourcentage population malnutrition'] = df_thai['Sous-nutrition']*100/df_thai['Population totale']

# %%
display(df_thai)
# Out:
#    index       Zone Année  Sous-nutrition  Population totale  \
# 0   1110  Thaïlande  2013       6200000.0         68144518.0
# 1   1111  Thaïlande  2014       6000000.0         68438746.0
# 2   1112  Thaïlande  2015       5900000.0         68714511.0
# 3   1113  Thaïlande  2016       6000000.0         68971308.0
# 4   1114  Thaïlande  2017       6200000.0         69209810.0
# 5   1115  Thaïlande  2018       6500000.0         69428453.0
#
#    Pourcentage population malnutrition
# 0                             9.098311
# 1                             8.766964
# 2                             8.586250
# 3                             8.699270
# 4                             8.958268
# 5                             9.362156

# %%
#Création d'une base de donnée pour la disponibilité alimentaire en Thaïlande, limitée au manioc et à son exportation
import_export_thai = dispo_alimentaire.loc[(dispo_alimentaire['Produit']=='Manioc') & (dispo_alimentaire['Zone']=='Thaïlande'),['Exportations - Quantité','Disponibilité intérieure']]

# %%
display(import_export_thai )
# Out:
#        Exportations - Quantité  Disponibilité intérieure
# 13809                  25214.0                    6264.0

# %%
#Création d'un graphique représentant la distribution de l'utilisation locale du manioc
display(import_export_thai )
values = import_export_thai.values.flatten()
plt.pie(x=values,  autopct='%.2f%%')
# Out:
#        Exportations - Quantité  Disponibilité intérieure
# 13809                  25214.0                    6264.0
# ([<matplotlib.patches.Wedge at 0x18540097b10>,
#   <matplotlib.patches.Wedge at 0x18540097ed0>],
#  [Text(-0.8919534431532444, 0.6437538778501238, ''),
#   Text(0.8919536529148355, -0.6437535872147676, '')],
#  [Text(-0.4865200599017696, 0.35113847882734023, '80.10%'),
#   Text(0.486520174317183, -0.3511383202989641, '19.90%')])

# %%
dispo_alim_thailand = dispo_alimentaire.loc[dispo_alimentaire['Zone']=='Thaïlande', :]

# %%
print(dispo_alim_thailand['Disponibilité alimentaire (Kcal/personne/jour)'].sum())
# Out:
# 2785.0

# %% [markdown]
# # Complément d'étude : accès aux protéines dans le monde

# %%
#Etude disponibilité protéines dans le monde

tri_prot = dispo_alimentaire.groupby('Zone').agg({'Disponibilité de protéines en quantité (g/personne/jour)': 'sum'})
tri_prot = tri_prot.sort_values('Disponibilité de protéines en quantité (g/personne/jour)')
prot_top5 = tri_prot.head(5)
prot_top5 = prot_top5.reset_index()
display(prot_top5)
prot_flop5 = tri_prot.tail(5)
prot_flop5 = prot_flop5.reset_index()
display(prot_flop5)
list_concat = [prot_top5, prot_flop5]
total_prot = pd.concat(list_concat)
total_prot = total_prot.reset_index()
display(total_prot)
# Out:
#                         Zone  \
# 0                    Libéria
# 1              Guinée-Bissau
# 2                 Mozambique
# 3  République centrafricaine
# 4                 Madagascar
#
#    Disponibilité de protéines en quantité (g/personne/jour)
# 0                                              37.66
# 1                                              44.05
# 2                                              45.68
# 3                                              46.04
# 4                                              46.69
#                        Zone  \
# 0                  Maldives
# 1                  Lituanie
# 2                    Israël
# 3  Chine - RAS de Hong-Kong
# 4                   Islande
#
#    Disponibilité de protéines en quantité (g/personne/jour)
# 0                                             122.32
# 1                                             124.36
# 2                                             128.00
# 3                                             129.07
# 4                                             133.06
#    index                       Zone  \
# 0      0                    Libéria
# 1      1              Guinée-Bissau
# 2      2                 Mozambique
# 3      3  République centrafricaine
# 4      4                 Madagascar
# 5      0                   Maldives
# 6      1                   Lituanie
# 7      2                     Israël
# 8      3   Chine - RAS de Hong-Kong
# 9      4                    Islande
#
#    Disponibilité de protéines en quantité (g/personne/jour)
# 0                                              37.66
# 1                                              44.05
# 2                                              45.68
# 3                                              46.04
# 4                                              46.69
# 5                                             122.32
# 6                                             124.36
# 7                                             128.00
# 8                                             129.07
# 9                                             133.06

# %%
plt.figure(figsize = (20, 10))
color_bar = ['burlywood','burlywood','burlywood','burlywood','burlywood', 'royalblue','royalblue','royalblue','royalblue','royalblue']
plt.bar(height = total_prot['Disponibilité de protéines en quantité (g/personne/jour)'], x = total_prot['Zone'], color =color_bar)
plt.title("Liste des 5 pays ayant le plus, et le moins, accès aux protéines", fontsize = 20)
plt.xlabel('Pays', fontsize = 18)
plt.ylabel('Disponibilité de protéines en quantité (g/personne/jour)', fontsize = 16)
plt.grid(axis = 'x')
plt.show()
